# %%
from semantic_kernel import Kernel
import os
from openai import OpenAI
from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.contents import FunctionCallContent, FunctionResultContent, StreamingTextContent
from openai import AsyncClient
from semantic_kernel.functions import kernel_function
from typing import Annotated
from IPython.display import display, HTML

# %%
import random   

# Define a sample plugin for the sample

class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Barcelona, Spain",
            "Paris, France",
            "Berlin, Germany",
            "Tokyo, Japan",
            "Sydney, Australia",
            "New York, USA",
            "Cairo, Egypt",
            "Cape Town, South Africa",
            "Rio de Janeiro, Brazil",
            "Bali, Indonesia"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
os.environ["GITHUB_TOKEN"] = "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"
token = os.environ["GITHUB_TOKEN"]
endpoint = "https://models.github.ai/inference"
model = "openai/gpt-4o"

client = AsyncClient(
    api_key=token,
    base_url=endpoint
)

chat_completion_service = OpenAIChatCompletion(ai_model_id=model, async_client=client)

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service, 
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %%
kernel = Kernel()
kernel.add_service(chat_completion_service)

# %%
user_inputs = [
    "Plan me a day trip.",
    "I don't like that destination. Plan me another vacation.",
]

async def main():
    thread: ChatHistoryAgentThread | None = None

    for user_input in user_inputs:
        html_output = (
            f"<div style='margin-bottom:10px'>"
            f"<div style='font-weight:bold'>User:</div>"
            f"<div style='margin-left:20px'>{user_input}</div></div>"
        )

        agent_name = None
        full_response: list[str] = []
        function_calls: list[str] = []

        # Buffer to reconstruct streaming function call
        current_function_name = None
        argument_buffer = ""

        async for response in agent.invoke_stream(
            messages=user_input,
            thread=thread,
        ):
            thread = response.thread
            agent_name = response.name
            content_items = list(response.items)

            for item in content_items:
                if isinstance(item, FunctionCallContent):
                    if item.function_name:
                        current_function_name = item.function_name

                    # Accumulate arguments (streamed in chunks)
                    if isinstance(item.arguments, str):
                        argument_buffer += item.arguments
                elif isinstance(item, FunctionResultContent):
                    # Finalize any pending function call before showing result
                    if current_function_name:
                        formatted_args = argument_buffer.strip()
                        try:
                            parsed_args = json.loads(formatted_args)
                            formatted_args = json.dumps(parsed_args)
                        except Exception:
                            pass  # leave as raw string

                        function_calls.append(f"Calling function: {current_function_name}({formatted_args})")
                        current_function_name = None
                        argument_buffer = ""

                    function_calls.append(f"\nFunction Result:\n\n{item.result}")
                elif isinstance(item, StreamingTextContent) and item.text:
                    full_response.append(item.text)

        if function_calls:
            html_output += (
                "<div style='margin-bottom:10px'>"
                "<details>"
                "<summary style='cursor:pointer; font-weight:bold; color:#0066cc;'>Function Calls (click to expand)</summary>"
                "<div style='margin:10px; padding:10px; background-color:#f8f8f8; "
                "border:1px solid #ddd; border-radius:4px; white-space:pre-wrap; font-size:14px; color:#333;'>"
                f"{chr(10).join(function_calls)}"
                "</div></details></div>"
            )

        html_output += (
            "<div style='margin-bottom:20px'>"
            f"<div style='font-weight:bold'>{agent_name or 'Assistant'}:</div>"
            f"<div style='margin-left:20px; white-space:pre-wrap'>{''.join(full_response)}</div></div><hr>"
        )

        display(HTML(html_output))

await main()
# Out:
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>Plan me a day trip.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>Your day trip destination is Bali, Indonesia! Here’s a suggested itinerary to make the most of your time in this beautiful tropical paradise:
#
# ### Morning:
# 1. **Breakfast at Kynd Community**: Start your day with a nutritious and Instagram-worthy breakfast at this famous cafe in Seminyak. Try their smoothie bowls or vegan pancakes.
#
# 2. **Explore Ubud's Rice Terraces**: Head to Ubud and visit the Tegallalang Rice Terraces. Take a leisurely walk through the lush, green fields and enjoy the serene atmosphere.
#
# ### Midday:
# 3. **Lunch at Locavore**: Stop by this award-winning restaurant in Ubud to indulge in a locally sourced and creative Balinese-inspired meal. Reservations are recommended.
#
# 4. **Visit Sacred Monkey Forest**: Walk among the friendly (and mischievous) monkeys in the Sacred Monkey Forest Sanctuary while admiring ancient temples tucked into the jungle.
#
# ### Afternoon:
# 5. **Tirta Empul Temple**: Head to this holy water temple in Tampaksiring to witness traditional cleansing rituals in the sacred springs. You can even participate if you wish.
#
# 6. **Coffee at a Local Plantation**: Visit a nearby coffee plantation to try the famous Luwak coffee and learn about how it's made.
#
# ### Evening:
# 7. **Sunset at Tanah Lot Temple**: End the day by witnessing a stunning sunset at this iconic sea temple situated on a rock formation in the ocean.
#
# 8. **Dinner by the Beach**: Head to Jimbaran Bay for fresh seafood while dining at one of the beachside cafes under the stars.
#
# ---
#
# Would you like help arranging transportation, accommodations, or any specific activities?</div></div><hr>
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>I don't like that destination. Plan me another vacation.</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>TravelAgent:</div><div style='margin-left:20px; white-space:pre-wrap'>Your next vacation destination is Paris, France! Here's a day trip itinerary to help you enjoy the charm of the City of Light:
#
# ### Morning:
# 1. **Breakfast at a Parisian Café**: Start your day with a classic French breakfast of croissants, pain au chocolat, and café au lait at a cozy corner café like Café de Flore or Les Deux Magots.
#
# 2. **Louvre Museum**: Visit the world-famous Louvre Museum to admire iconic masterpieces like the Mona Lisa and Venus de Milo. Spend a few hours exploring its vast art collection.
#
# ### Midday:
# 3. **Picnic Lunch by the Seine**: Pick up some fresh baguettes, cheese, and fruit from a local market and enjoy a picnic along the Seine River or in the Tuileries Garden.
#
# 4. **Notre Dame Cathedral**: Stroll over to the Île de la Cité to admire the stunning Gothic architecture of Notre Dame. Though the interior is under restoration, the exterior is still breathtaking.
#
# ### Afternoon:
# 5. **Walk Along the Champs-Élysées**: Take a leisurely walk along this famous avenue, ending at the Arc de Triomphe. If you're feeling adventurous, climb to the top for panoramic views of the city.
#
# 6. **Montmartre and Sacré-Cœur**: Head to the artsy neighborhood of Montmartre to explore its cobblestone streets, local art, and charming vibe. Be sure to visit the Basilica of the Sacré-Cœur for another stunning view of Paris.
#
# ### Evening:
# 7. **Dinner at a Traditional French Bistro**: Dine at a cozy bistro like Le Comptoir du Relais or Bistrot Paul Bert to enjoy authentic French cuisine such as coq au vin or steak frites.
#
# 8. **Seine River Cruise**: End your day with a magical Seine River cruise. You'll see the Eiffel Tower, Notre Dame, and other key landmarks beautifully lit up at night.
#
# Would you like suggestions for shorter trips, activities tailored to your interests, or help with bookings?</div></div><hr>
